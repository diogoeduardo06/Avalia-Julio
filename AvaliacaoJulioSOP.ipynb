# %%
# !pip install mysql-connector-python==8.0.32
# Out:
# Requirement already satisfied: mysql-connector-python==8.0.32 in /usr/local/lib/python3.11/dist-packages (8.0.32)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from mysql-connector-python==8.0.32) (3.20.3)

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="avaliacaosop.c3jksgqqsn6r.us-east-1.rds.amazonaws.com",
  user="admin",
  password="12345678"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE primeiraTBL")
